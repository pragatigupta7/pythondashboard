# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Sales Data.csv")
df
# Out:
#          s.no  Order ID       Product Category                 Product  \
# 0           0    295665  Laptops and Computers      Macbook Pro Laptop
# 1           1    295666        Home Appliances      LG Washing Machine
# 2           2    295667        Charging Cables    USB-C Charging Cable
# 3           3    295668               Monitors        27in FHD Monitor
# 4           4    295669        Charging Cables    USB-C Charging Cable
# ...       ...       ...                    ...                     ...
# 185945  13617    222905               Batterie  AAA Batteries (4-pack)
# 185946  13618    222906               Monitors        27in FHD Monitor
# 185947  13619    222907        Charging Cables    USB-C Charging Cable
# 185948  13620    222908        Charging Cables    USB-C Charging Cable
# 185949  13621    222909               Batterie  AAA Batteries (4-pack)
#
#         Quantity Ordered  Price Each        Order Date  \
# 0                      1     1700.00  30-12-2019 00:01
# ...

# %%
df.head()
# Out:
#    s.no  Order ID       Product Category               Product  \
# 0     0    295665  Laptops and Computers    Macbook Pro Laptop
# 1     1    295666        Home Appliances    LG Washing Machine
# 2     2    295667        Charging Cables  USB-C Charging Cable
# 3     3    295668               Monitors      27in FHD Monitor
# 4     4    295669        Charging Cables  USB-C Charging Cable
#
#    Quantity Ordered  Price Each        Order Date  \
# 0                 1     1700.00  30-12-2019 00:01
# 1                 1      600.00  29-12-2019 07:03
# 2                 1       11.95  12/12/2019 18:21
# 3                 1      149.99  22-12-2019 15:13
# 4                 1       11.95  18-12-2019 12:38
#
#                          Purchase Address  Month    Sales            City  \
# 0  136 Church St, New York City, NY 10001     12  1700.00   New York City
# 1     562 2nd St, New York City, NY 10001     12   600.00   New York City
# ...

# %%
df.shape
# Out:
# (185950, 13)

# %%
df.columns = [str(name).lower() for name in df.columns.tolist()]
df.head(5)
# Out:
#    s.no  order id       product category               product  \
# 0     0    295665  Laptops and Computers    Macbook Pro Laptop
# 1     1    295666        Home Appliances    LG Washing Machine
# 2     2    295667        Charging Cables  USB-C Charging Cable
# 3     3    295668               Monitors      27in FHD Monitor
# 4     4    295669        Charging Cables  USB-C Charging Cable
#
#    quantity ordered  price each        order date  \
# 0                 1     1700.00  30-12-2019 00:01
# 1                 1      600.00  29-12-2019 07:03
# 2                 1       11.95  12/12/2019 18:21
# 3                 1      149.99  22-12-2019 15:13
# 4                 1       11.95  18-12-2019 12:38
#
#                          purchase address  month    sales            city  \
# 0  136 Church St, New York City, NY 10001     12  1700.00   New York City
# 1     562 2nd St, New York City, NY 10001     12   600.00   New York City
# ...

# %%
df.columns
# Out:
# Index(['s.no', 'order id', 'product category', 'product', 'quantity ordered',
#        'price each', 'order date', 'purchase address', 'month', 'sales',
#        'city', 'hour', 'time of day'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# s.no                0
# order id            0
# product category    0
# product             0
# quantity ordered    0
# price each          0
# order date          0
# purchase address    0
# month               0
# sales               0
# city                0
# hour                0
# time of day         0
# dtype: int64

# %%
plt.figure(figsize=(17,5))
sns.countplot(x="product category",data=df)
plt.title("count of a product category")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="product",data=df)
plt.savefig("product wise sales count")
plt.show()

# %%
df['time of day'].value_counts()
# Out:
# time of day
# Afternoon    67158
# Evening      63431
# Morning      44852
# Night        10509
# Name: count, dtype: int64

# %%
x=df['time of day'].value_counts().index
y=df['time of day'].value_counts().values
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="city",data=df,hue="product category")
plt.show()

# %%
df
# Out:
#          s.no  order id       product category                 product  \
# 0           0    295665  Laptops and Computers      Macbook Pro Laptop
# 1           1    295666        Home Appliances      LG Washing Machine
# 2           2    295667        Charging Cables    USB-C Charging Cable
# 3           3    295668               Monitors        27in FHD Monitor
# 4           4    295669        Charging Cables    USB-C Charging Cable
# ...       ...       ...                    ...                     ...
# 185945  13617    222905               Batterie  AAA Batteries (4-pack)
# 185946  13618    222906               Monitors        27in FHD Monitor
# 185947  13619    222907        Charging Cables    USB-C Charging Cable
# 185948  13620    222908        Charging Cables    USB-C Charging Cable
# 185949  13621    222909               Batterie  AAA Batteries (4-pack)
#
#         quantity ordered  price each        order date  \
# 0                      1     1700.00  30-12-2019 00:01
# ...

# %%
df['order date'].value_counts()
# Out:
# order date
# 15-12-2019 20:16    8
# 30-10-2019 21:28    7
# 2/4/2019 13:24      7
# 11/12/2019 13:24    7
# 11/10/2019 19:44    6
#                    ..
# 6/8/2019 8:32       1
# 18-08-2019 20:27    1
# 30-08-2019 16:29    1
# 15-08-2019 14:05    1
# 25-06-2019 14:33    1
# Name: count, Length: 142395, dtype: int64

# %%
total_rows = df.shape[0]
total_rows
# Out:
# 185950

# %%
df
# Out:
#          s.no  order id       product category                 product  \
# 0           0    295665  Laptops and Computers      Macbook Pro Laptop
# 1           1    295666        Home Appliances      LG Washing Machine
# 2           2    295667        Charging Cables    USB-C Charging Cable
# 3           3    295668               Monitors        27in FHD Monitor
# 4           4    295669        Charging Cables    USB-C Charging Cable
# ...       ...       ...                    ...                     ...
# 185945  13617    222905               Batterie  AAA Batteries (4-pack)
# 185946  13618    222906               Monitors        27in FHD Monitor
# 185947  13619    222907        Charging Cables    USB-C Charging Cable
# 185948  13620    222908        Charging Cables    USB-C Charging Cable
# 185949  13621    222909               Batterie  AAA Batteries (4-pack)
#
#         quantity ordered  price each        order date  \
# 0                      1     1700.00  30-12-2019 00:01
# ...

# %%
# Convert order_date to datetime
df['order date'] = pd.to_datetime(df['order date'],dayfirst=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Convert order_date to datetime
# ----> 2 df['order date'] = pd.to_datetime(df['order date'],dayfirst=True)
#
# File c:\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
# Calculate total sales
df['total_sales'] = df['quantity ordered'] * df['price each']
total_sales=df['total_sales']
fig = plt.hist(total_sales )

# %%
df["purchase address"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         136 Church St, New York City, NY 10001
# 1            562 2nd St, New York City, NY 10001
# 2           277 Main St, New York City, NY 10001
# 3            410 6th St, San Francisco, CA 94016
# 4                  43 Hill St, Atlanta, GA 30301
#                            ...
# 185945             795 Pine St, Boston, MA 02215
# 185946     495 North St, New York City, NY 10001
# 185947     319 Ridge St, San Francisco, CA 94016
# 185948      916 Main St, San Francisco, CA 94016
# 185949            209 11th St, Atlanta, GA 30301
# Name: purchase address, Length: 185950, dtype: object>

# %%
df["purchase address"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         136 Church St, New York City, NY 10001
# 1            562 2nd St, New York City, NY 10001
# 2           277 Main St, New York City, NY 10001
# 3            410 6th St, San Francisco, CA 94016
# 4                  43 Hill St, Atlanta, GA 30301
#                            ...
# 185945             795 Pine St, Boston, MA 02215
# 185946     495 North St, New York City, NY 10001
# 185947     319 Ridge St, San Francisco, CA 94016
# 185948      916 Main St, San Francisco, CA 94016
# 185949            209 11th St, Atlanta, GA 30301
# Name: purchase address, Length: 185950, dtype: object>

# %%
df

# %%
total_sales = df['sales'].sum()
plt.hist(df['sales'], bins=10, edgecolor='black')
# Add title and labels
plt.title('Histogram')
plt.xlabel('sales')
plt.ylabel('price each')

# Show plot
plt.show()

# %%
cities_list = df['city'].tolist()
sales_list = df['sales'].tolist()
# Group by city and sum the sales
city_sales = df.groupby('cities_list')['sales_list'].sum().reset_index()

# Display the city-wise sales
print(city_sales)

# Plot the bar graph for city-wise sales
plt.figure(figsize=(10, 6))
plt.bar(city_sales['cities_list'], city_sales['sales_list'], color='skyblue', edgecolor='black')

# Add title and labels
plt.title('City-wise Sales')
plt.xlabel('city')
plt.ylabel('Total Sales')

# Rotate city names for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 4
#       2 sales_list = df['sales'].tolist()
#       3 # Group by city and sum the sales
# ----> 4 city_sales = df.groupby('cities_list')['sales_list'].sum().reset_index()
#       6 # Display the city-wise sales
#       7 print(city_sales)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
df.columns
# Out:
# Index(['s.no', 'order id', 'product category', 'product', 'quantity ordered',
#        'price each', 'order date', 'purchase address', 'month', 'sales',
#        'city', 'hour', 'time of day', 'total_sales'],
#       dtype='object')

# %%
df.info('month')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   s.no              185950 non-null  int64
#  1   order id          185950 non-null  int64
#  2   product category  185950 non-null  object
#  3   product           185950 non-null  object
#  4   quantity ordered  185950 non-null  int64
#  5   price each        185950 non-null  float64
#  6   order date        185950 non-null  object
#  7   purchase address  185950 non-null  object
#  8   month             185950 non-null  int64
#  9   sales             185950 non-null  float64
#  10  city              185950 non-null  object
#  11  hour              185950 non-null  int64
#  12  time of day       185950 non-null  object
#  13  total_sales       185950 non-null  float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 19.9+ MB

# %%
ax=sns.countplot(x='month',data=df)

# %%
ax=sns.countplot(x='month',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df
# Out:
#          s.no  order id       product category                 product  \
# 0           0    295665  Laptops and Computers      Macbook Pro Laptop
# 1           1    295666        Home Appliances      LG Washing Machine
# 2           2    295667        Charging Cables    USB-C Charging Cable
# 3           3    295668               Monitors        27in FHD Monitor
# 4           4    295669        Charging Cables    USB-C Charging Cable
# ...       ...       ...                    ...                     ...
# 185945  13617    222905               Batterie  AAA Batteries (4-pack)
# 185946  13618    222906               Monitors        27in FHD Monitor
# 185947  13619    222907        Charging Cables    USB-C Charging Cable
# 185948  13620    222908        Charging Cables    USB-C Charging Cable
# 185949  13621    222909               Batterie  AAA Batteries (4-pack)
#
#         quantity ordered  price each        order date  \
# 0                      1     1700.00  30-12-2019 00:01
# ...

# %%
df.groupby(['sales'],as_index=False)['quantity ordered'].sum().sort_values(by='quantity ordered',ascending=False)
# Out:
#       sales  quantity ordered
# 9     14.95             21040
# 6     11.95             20019
# 8     11.99             17361
# 32   150.00             15438
# 1      3.84             15333
# 0      2.99             13726
# 29    99.99             13195
# 2      5.98              9260
# 3      7.68              7748
# 31   149.99              7464
# 42   600.00              6868
# 43   700.00              6835
# 39   389.99              6216
# 38   379.99              6163
# 37   300.00              5001
# 50  1700.00              4720
# 4      8.97              4506
# 47   999.99              4126
# 30   109.99              4073
# 15    23.90              3426
# 5     11.52              3099
# 17    23.98              2760
# 20    29.90              2688
# 7     11.96              2096
# 40   400.00              2062
# 10    15.36              1000
# 21    35.85               471
# 22    35.97               384
# 11    17.94               378
# 12    19.20               345
# ...

# %%
plt.figure(figsize=(20,5))
sales=df.groupby(['price each'],as_index=False)['quantity ordered'].sum().sort_values(by='quantity ordered',ascending=False)
sns.barplot(x='price each',y='quantity ordered',data=sales)
# Out:
# <Axes: xlabel='price each', ylabel='quantity ordered'>

# %%
df['month'].hist()
# Out:
# <Axes: >

# %%
df['product category']=df['product category'].astype(str)
column_data=df['product category']
plt.figure(figsize=(10,5))
plt.hist(column_data,bins=30,edgecolor='black')
plt.xticks(rotation=90)
plt.show()

# %%
df['product']=df['product'].astype(str)
column_data=df['product']
plt.figure(figsize=(10,5))
plt.hist(column_data,bins=30,edgecolor='black')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#          s.no  order id       product category                 product  \
# 0           0    295665  Laptops and Computers      Macbook Pro Laptop
# 1           1    295666        Home Appliances      LG Washing Machine
# 2           2    295667        Charging Cables    USB-C Charging Cable
# 3           3    295668               Monitors        27in FHD Monitor
# 4           4    295669        Charging Cables    USB-C Charging Cable
# ...       ...       ...                    ...                     ...
# 185945  13617    222905               Batterie  AAA Batteries (4-pack)
# 185946  13618    222906               Monitors        27in FHD Monitor
# 185947  13619    222907        Charging Cables    USB-C Charging Cable
# 185948  13620    222908        Charging Cables    USB-C Charging Cable
# 185949  13621    222909               Batterie  AAA Batteries (4-pack)
#
#         quantity ordered  price each        order date  \
# 0                      1     1700.00  30-12-2019 00:01
# ...

# %%
x_data =df['product']
y_data=df['sales']
plt.scatter(x_data,y_data)

plt.xlabel('product')
plt.ylabel('sales')
plt.title('scatter plot')
plt.xticks(rotation=90)
plt.show()
